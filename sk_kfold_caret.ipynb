# %% [markdown]
# # sklearnで、交差検証ありのコード

# %%
import numpy as np
import pandas as pd
from pprint import pprint

from sklearn.datasets import load_iris
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier

from sklearn.model_selection import cross_validate, StratifiedKFold, train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score

# %% [markdown]
# # データセットを取得

# %%
# データの読み込み
iris=load_iris()
X,y=iris.data,iris.target

# 行・列数の確認
print(X.shape)
print(y.shape)
# Out:
# (150, 4)
# (150,)

# %% [markdown]
# # 交差検証で、foldごとにモデルを訓練

# %%
# データ
kf = KFold(n_splits=5, shuffle=True)
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
                      
scores=[]
#scoring = {"acc":"accuracy", "prc": "precision_macro","rec": "recall_macro", "f1":"f1_macro", "auc":"roc_auc"}
scoring = {"acc":"accuracy", "prc": "precision_macro","rec": "recall_macro", "f1":"f1_macro"}


# KFoldで、分割して作成されたデータセットのインデックスを取得できる
for train_id, test_id in kf.split(X):
    train_x = X[train_id]
    train_y = y[train_id]
    test_x = X[test_id]
    test_y = y[test_id]
    
    print("==="*40)
    # モデルを設定
    clf=DecisionTreeClassifier(max_depth=3, random_state=94)
    # モデルの学習
    clf.fit(train_x, train_y)
    
    # 推論
    pred_y = clf.predict(test_x)
    # 精度指標の取得
    #scores_cv = cross_validate(clf, iris.data, iris.target, cv=skf, scoring=scoring)
    scores_cv = cross_validate(clf, X=train_x, y=train_y, cv=kf, scoring=scoring)
    pprint(scores_cv)
    
    score=accuracy_score(test_y, pred_y)
    scores.append(score)

#
print("==="*40)
print("\n")

scores = np.array(scores)
print(scores.mean())
# Out:
# ========================================================================================================================
# {'fit_time': array([0.        , 0.00099993, 0.        , 0.        , 0.00099993]),
#  'score_time': array([0.0019989 , 0.00100064, 0.00200009, 0.00200033, 0.00099969]),
#  'test_acc': array([0.95833333, 0.91666667, 1.        , 0.95833333, 0.875     ]),
#  'test_f1': array([0.95681511, 0.91111111, 1.        , 0.95213675, 0.9047619 ]),
#  'test_prc': array([0.95238095, 0.91111111, 1.        , 0.95238095, 0.91666667]),
#  'test_rec': array([0.96666667, 0.91111111, 1.        , 0.95833333, 0.91666667])}
# ========================================================================================================================
# {'fit_time': array([0.        , 0.        , 0.        , 0.        , 0.00100017]),
#  'score_time': array([0.00199986, 0.00199962, 0.00200009, 0.00200033, 0.00099993]),
#  'test_acc': array([0.91666667, 0.95833333, 0.91666667, 1.        , 0.91666667]),
#  'test_f1': array([0.92207792, 0.95213675, 0.91071429, 1.        , 0.90740741]),
#  'test_prc': array([0.94444444, 0.95238095, 0.92592593, 1.        , 0.9047619 ]),
#  'test_rec': array([0.91666667, 0.95833333, 0.91666667, 1.        , 0.93333333])}
# ========================================================================================================================
# {'fit_time': array([0.00099921, 0.        , 0.        , 0.        , 0.        ]),
#  'score_time': array([0.00099993, 0.00100017, 0.00099993, 0.00100017, 0.0010004 ]),
#  'test_acc': array([1.        , 0.95833333, 1.        , 0.875     , 0.95833333]),
#  'test_f1': array([1.        , 0.95816993, 1.        , 0.85641026, 0.95215311]),
#  'test_prc': array([1.        , 0.96296296, 1.        , 0.88888889, 0.96666667]),
#  'test_rec': array([1.        , 0.95833333, 1.        , 0.875     , 0.94444444])}
# ========================================================================================================================
# {'fit_time': array([0.0010376 , 0.00100017, 0.00100303, 0.00100112, 0.00100064]),
#  'score_time': array([0.00099921, 0.0010004 , 0.00099826, 0.00099683, 0.00100017]),
#  'test_acc': array([1.        , 1.        , 0.95833333, 1.        , 0.91666667]),
#  'test_f1': array([1.        , 1.        , 0.95215311, 1.        , 0.91071429]),
#  'test_prc': array([1.        , 1.        , 0.94444444, 1.        , 0.91666667]),
#  'test_rec': array([1.        , 1.        , 0.96666667, 1.        , 0.92592593])}
# ========================================================================================================================
# {'fit_time': array([0.00100088, 0.        , 0.        , 0.00100017, 0.00099945]),
#  'score_time': array([0.00197005, 0.00202751, 0.00199962, 0.00100088, 0.00100565]),
#  'test_acc': array([1.        , 0.91666667, 0.875     , 0.95833333, 0.875     ]),
#  'test_f1': array([1.        , 0.925     , 0.88070175, 0.95213675, 0.88235294]),
#  'test_prc': array([1.        , 0.925     , 0.88888889, 0.95833333, 0.9       ]),
#  'test_rec': array([1.        , 0.925     , 0.90909091, 0.95238095, 0.9       ])}
# ========================================================================================================================
#
#
# 0.9533333333333334

# %% [markdown]
# # Pycaretと組み合わせる

# %%
#!pip install pycaret

# %%
# パッケージの読み込み
import pandas as pd
from pycaret.classification import *
#from pycaret.regression import *
from pycaret.datasets import get_data

#boston = get_data('boston')
#exp1 = setup(boston_data, target = 'medv')

# %% [markdown]
# # 使用するデータの読み込み
# from pycaret.datasets import get_data
# data = get_data('employee')

# %% [markdown]
# # 95％を学習データ、5%をテストデータ(Unseen Dataと呼ぶ)に分ける
# employee_data = data.sample(frac =0.95, random_state = 786).reset_index(drop=True)
# employee_data_unseen = data.drop(employee_data.index).reset_index(drop=True)
# print('Data for Modeling: ' + str(employee_data.shape))
# print('Unseen Data For Predictions: ' + str(employee_data_unseen.shape))

# %%
df_x = pd.DataFrame(X)
df_ = pd.concat([df_x, pd.DataFrame(y)])

# %%
df_.head()
# Out:
#      0    1    2    3
# 0  5.1  3.5  1.4  0.2
# 1  4.9  3.0  1.4  0.2
# 2  4.7  3.2  1.3  0.2
# 3  4.6  3.1  1.5  0.2
# 4  5.0  3.6  1.4  0.2

# %%
iris = load_iris()
X_a = pd.DataFrame(iris.data, columns=iris.feature_names)
y_a = pd.DataFrame(iris.target, columns=["target"])
df_a = pd.concat([X_a,y_a], axis=1)
df_a.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
# PyCaretを起動
exp1 = setup(df_a, target = 'target')
#exp1 = setup(df_x, target=df_y, ignore_features = None)
# PyCaretを起動（データ型を変更する場合）
#exp1 = setup(employee_data, target = 'left', ignore_features = None, numeric_features = ['time_spend_company'])
# Out:
# <style  type="text/css" >
# #T_4af85_row44_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_4af85_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4af85_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4af85_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_4af85_row0_col1" class="data row0 col1" >4434</td>
#             </tr>
#             <tr>
#                         <th id="T_4af85_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4af85_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_4af85_row1_col1" class="data row1 col1" >target</td>
#             </tr>
#             <tr>
#                         <th id="T_4af85_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_4af85_row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_4af85_row2_col1" class="data row2 col1" >Multiclass</td>
#             </tr>
#             <tr>
#                         <th id="T_4af85_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_4af85_row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_4af85_row3_col1" class="data row3 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_4af85_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_4af85_row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_4af85_row4_col1" class="data row4 col1" >(150, 5)</td>
#             </tr>
#             <tr>
#                         <th id="T_4af85_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_4af85_row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_4af85_row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4af85_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_4af85_row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_4af85_row6_col1" class="data row6 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_4af85_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_4af85_row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_4af85_row7_col1" class="data row7 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_4af85_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_4af85_row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_4af85_row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4af85_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_4af85_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_4af85_row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4af85_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_4af85_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_4af85_row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_4af85_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_4af85_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_4af85_row11_col1" class="data row11 col1" >(104, 4)</td>
#             </tr>
#             <tr>
#                         <th id="T_4af85_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_4af85_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_4af85_row12_col1" class="data row12 col1" >(46, 4)</td>
#             </tr>
#             <tr>
#                         <th id="T_4af85_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_4af85_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_4af85_row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_4af85_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_4af85_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_4af85_row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4af85_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_4af85_row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_4af85_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_4af85_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_4af85_row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_4af85_row16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_4af85_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_4af85_row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_4af85_row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_4af85_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_4af85_row18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_4af85_row18_col1" class="data row18 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4af85_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_4af85_row19_col0" class="data row19 col0" >Log Experiment</td>
#                         <td id="T_4af85_row19_col1" class="data row19 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4af85_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_4af85_row20_col0" class="data row20 col0" >Experiment Name</td>
#                         <td id="T_4af85_row20_col1" class="data row20 col1" >clf-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_4af85_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_4af85_row21_col0" class="data row21 col0" >USI</td>
#                         <td id="T_4af85_row21_col1" class="data row21 col1" >1a6f</td>
#             </tr>
#             <tr>
#                         <th id="T_4af85_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_4af85_row22_col0" class="data row22 col0" >Imputation Type</td>
#                         <td id="T_4af85_row22_col1" class="data row22 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_4af85_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_4af85_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_4af85_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_4af85_level0_row24" class="row_heading level0 row24" >24</th>

# %%
# モデルの比較
compare_models()
# Out:
# <style  type="text/css" >
#     #T_2948f_ th {
#           text-align: left;
#     }#T_2948f_row0_col0,#T_2948f_row1_col0,#T_2948f_row1_col1,#T_2948f_row1_col3,#T_2948f_row1_col4,#T_2948f_row1_col5,#T_2948f_row1_col6,#T_2948f_row1_col7,#T_2948f_row2_col0,#T_2948f_row2_col1,#T_2948f_row2_col3,#T_2948f_row2_col4,#T_2948f_row2_col5,#T_2948f_row2_col6,#T_2948f_row2_col7,#T_2948f_row3_col0,#T_2948f_row3_col1,#T_2948f_row3_col2,#T_2948f_row3_col3,#T_2948f_row3_col4,#T_2948f_row3_col5,#T_2948f_row3_col6,#T_2948f_row3_col7,#T_2948f_row4_col0,#T_2948f_row4_col1,#T_2948f_row4_col3,#T_2948f_row4_col4,#T_2948f_row4_col5,#T_2948f_row4_col6,#T_2948f_row4_col7,#T_2948f_row5_col0,#T_2948f_row5_col1,#T_2948f_row5_col2,#T_2948f_row5_col3,#T_2948f_row5_col4,#T_2948f_row5_col5,#T_2948f_row5_col6,#T_2948f_row5_col7,#T_2948f_row6_col0,#T_2948f_row6_col1,#T_2948f_row6_col2,#T_2948f_row6_col3,#T_2948f_row6_col4,#T_2948f_row6_col5,#T_2948f_row6_col6,#T_2948f_row6_col7,#T_2948f_row7_col0,#T_2948f_row7_col1,#T_2948f_row7_col2,#T_2948f_row7_col3,#T_2948f_row7_col4,#T_2948f_row7_col5,#T_2948f_row7_col6,#T_2948f_row7_col7,#T_2948f_row8_col0,#T_2948f_row8_col1,#T_2948f_row8_col3,#T_2948f_row8_col4,#T_2948f_row8_col5,#T_2948f_row8_col6,#T_2948f_row8_col7,#T_2948f_row9_col0,#T_2948f_row9_col1,#T_2948f_row9_col2,#T_2948f_row9_col3,#T_2948f_row9_col4,#T_2948f_row9_col5,#T_2948f_row9_col6,#T_2948f_row9_col7,#T_2948f_row10_col0,#T_2948f_row10_col1,#T_2948f_row10_col2,#T_2948f_row10_col3,#T_2948f_row10_col4,#T_2948f_row10_col5,#T_2948f_row10_col6,#T_2948f_row10_col7,#T_2948f_row11_col0,#T_2948f_row11_col1,#T_2948f_row11_col2,#T_2948f_row11_col3,#T_2948f_row11_col4,#T_2948f_row11_col5,#T_2948f_row11_col6,#T_2948f_row11_col7,#T_2948f_row12_col0,#T_2948f_row12_col1,#T_2948f_row12_col2,#T_2948f_row12_col3,#T_2948f_row12_col4,#T_2948f_row12_col5,#T_2948f_row12_col6,#T_2948f_row12_col7{
#             text-align:  left;
#             text-align:  left;
#         }#T_2948f_row0_col1,#T_2948f_row0_col2,#T_2948f_row0_col3,#T_2948f_row0_col4,#T_2948f_row0_col5,#T_2948f_row0_col6,#T_2948f_row0_col7,#T_2948f_row1_col2,#T_2948f_row2_col2,#T_2948f_row4_col2,#T_2948f_row8_col2{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_2948f_row0_col8,#T_2948f_row1_col8,#T_2948f_row2_col8,#T_2948f_row3_col8,#T_2948f_row4_col8,#T_2948f_row5_col8,#T_2948f_row6_col8,#T_2948f_row7_col8,#T_2948f_row8_col8,#T_2948f_row9_col8,#T_2948f_row10_col8,#T_2948f_row12_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_2948f_row11_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_2948f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2948f_level0_row0" class="row_heading level0 row0" >gbc</th>
#                         <td id="T_2948f_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#                         <td id="T_2948f_row0_col1" class="data row0 col1" >1.0000</td>
#                         <td id="T_2948f_row0_col2" class="data row0 col2" >1.0000</td>
#                         <td id="T_2948f_row0_col3" class="data row0 col3" >1.0000</td>
#                         <td id="T_2948f_row0_col4" class="data row0 col4" >1.0000</td>
#                         <td id="T_2948f_row0_col5" class="data row0 col5" >1.0000</td>
#                         <td id="T_2948f_row0_col6" class="data row0 col6" >1.0000</td>
#                         <td id="T_2948f_row0_col7" class="data row0 col7" >1.0000</td>
#                         <td id="T_2948f_row0_col8" class="data row0 col8" >0.0260</td>
#             </tr>
#             <tr>
#                         <th id="T_2948f_level0_row1" class="row_heading level0 row1" >qda</th>
#                         <td id="T_2948f_row1_col0" class="data row1 col0" >Quadratic Discriminant Analysis</td>
#                         <td id="T_2948f_row1_col1" class="data row1 col1" >0.9909</td>
#                         <td id="T_2948f_row1_col2" class="data row1 col2" >1.0000</td>
#                         <td id="T_2948f_row1_col3" class="data row1 col3" >0.9917</td>
#                         <td id="T_2948f_row1_col4" class="data row1 col4" >0.9927</td>
#                         <td id="T_2948f_row1_col5" class="data row1 col5" >0.9908</td>
#                         <td id="T_2948f_row1_col6" class="data row1 col6" >0.9862</td>
#                         <td id="T_2948f_row1_col7" class="data row1 col7" >0.9873</td>
#                         <td id="T_2948f_row1_col8" class="data row1 col8" >0.0030</td>
#             </tr>
#             <tr>
#                         <th id="T_2948f_level0_row2" class="row_heading level0 row2" >lda</th>
#                         <td id="T_2948f_row2_col0" class="data row2 col0" >Linear Discriminant Analysis</td>
#                         <td id="T_2948f_row2_col1" class="data row2 col1" >0.9909</td>
#                         <td id="T_2948f_row2_col2" class="data row2 col2" >1.0000</td>
#                         <td id="T_2948f_row2_col3" class="data row2 col3" >0.9917</td>
#                         <td id="T_2948f_row2_col4" class="data row2 col4" >0.9927</td>
#                         <td id="T_2948f_row2_col5" class="data row2 col5" >0.9908</td>
#                         <td id="T_2948f_row2_col6" class="data row2 col6" >0.9862</td>
#                         <td id="T_2948f_row2_col7" class="data row2 col7" >0.9873</td>
#                         <td id="T_2948f_row2_col8" class="data row2 col8" >0.0030</td>
#             </tr>
#             <tr>
#                         <th id="T_2948f_level0_row3" class="row_heading level0 row3" >dt</th>
#                         <td id="T_2948f_row3_col0" class="data row3 col0" >Decision Tree Classifier</td>
#                         <td id="T_2948f_row3_col1" class="data row3 col1" >0.9900</td>
#                         <td id="T_2948f_row3_col2" class="data row3 col2" >0.9917</td>
#                         <td id="T_2948f_row3_col3" class="data row3 col3" >0.9889</td>
#                         <td id="T_2948f_row3_col4" class="data row3 col4" >0.9920</td>
#                         <td id="T_2948f_row3_col5" class="data row3 col5" >0.9896</td>
#                         <td id="T_2948f_row3_col6" class="data row3 col6" >0.9846</td>
#                         <td id="T_2948f_row3_col7" class="data row3 col7" >0.9860</td>
#                         <td id="T_2948f_row3_col8" class="data row3 col8" >0.0030</td>
#             </tr>
#             <tr>
#                         <th id="T_2948f_level0_row4" class="row_heading level0 row4" >ada</th>
#                         <td id="T_2948f_row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#                         <td id="T_2948f_row4_col1" class="data row4 col1" >0.9818</td>
#                         <td id="T_2948f_row4_col2" class="data row4 col2" >1.0000</td>
#                         <td id="T_2948f_row4_col3" class="data row4 col3" >0.9833</td>
#                         <td id="T_2948f_row4_col4" class="data row4 col4" >0.9855</td>
#                         <td id="T_2948f_row4_col5" class="data row4 col5" >0.9815</td>
#                         <td id="T_2948f_row4_col6" class="data row4 col6" >0.9725</td>
#                         <td id="T_2948f_row4_col7" class="data row4 col7" >0.9747</td>
#                         <td id="T_2948f_row4_col8" cla
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=4434, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)
